# %% [markdown]
# <a href="https://colab.research.google.com/github/ava11235/it125/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # **Data Classification with K Nearest Neighbors(KNN)**
#
# ## **Learning Outcomes**
#
# Upon successful completion of the material, students will be able to:
# * Describe what the K Nearest Neighbour (KNN) classification model is
# * Identify use cases and applications for KNN
# * Run starter Python code that Implements a KNN classifier in the cloud
# * Visualize the KNN classifier results with the appropriate data visualization chart
#
# ## **K Nearest Neighbors**
#
# ** Machine Learning (ML) ** is used for automatically finding patterns in data, often big data, and for making inferences and predictions. In this lecture we focus on the KNN ML classification technique.
#
#
# **Classification** is about learning how to make predictions from past data. Given a dataset where the prediction is known to be correct, we can use this data to make predictions for future observations in the dataset.
#
# Let's take a look at a couple examples:
#
# 1. ** Text Classifier:  Inbox or Spam? **
#
# ![Classfier](https://developers.google.com/machine-learning/guides/text-classification/images/TextClassificationExample.png)
#
#
# 2. **Does a patient have chronic kidney disease?**
#
# Based on existing blood test measurements of patients diagnosed with chronic kidney disease, we can infer that these measurements tend to be characteristic of chronic kidney disease  New patients whose labs show similar measurements will be diagnosed accordingly.
# In the below image dark blue means chronic kidney disease, yellow means no chronic kidney disease.
#
#
# ![Nearest_Neighbors_26_0.png](data:image/png;base64,...)
#
#
#
#
#
# ## **How does KNN make recommendations?**
#
# KNN  is a machine learning method that uses the k closest observations (aka nearest neighbors) to make a recommendation about an observation.
#
# In KNN, K is the number of nearest neighbors. **The number of neighbors is the core deciding factor. **
#
# For finding closest similar points, the distance between points  is measured (known as Euclidean distance).
#
# Choosing k depends on the data. An odd value between 1 and 20 is a good starting point.
#
# ```
# In classification, the prediction result is a binary answer (Yes/No).
#
# The classifier need not be 100% accurate to be useful.
# The collection of existing, pre-classified observations is referred to as the training set. The classification algorithm analayzes the training set and returns a classifier class of the future observations.
# ```
#
#
#
# ## **Practice**
#
# Take a look at the image below. We want to classify the green dot as a red triangle or blue square.
#
# How will the green circle be classified when k = 3?
#
# What about when k = 5?
#
# ```A smaller k value results in a detailed model, but it can  overfit (too good to be true). A larger k value reduces noise and yields smoother class boundaries, but can underfit (too simple to explain the variance).  ```
#
# ![KNN Img](https://upload.wikimedia.org/wikipedia/commons/e/e7/KnnClassification.svg)

# %% [markdown]
#  ## Example
#
#
# ![iris](https://upload.wikimedia.org/wikipedia/commons/9/9f/Iris_virginica.jpg)
#
#
# This is a scikit-learn example for implementing a KNN classifier in Python.
# You can run the code cell as demonstrated in class and explore the code further, making use of the comments and documentation references.
#
# The below example demonstrates how to classify a dataset of Iris flowers based on their sepal length and width. Sepals are the green parts that protect the bud of the flower.  The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The type of plant (species) is classified in one of these classes:
#
# * Iris Setosa (0)
#
# * Iris Versicolour (1)
#
# * Iris Virginica (2)
#
# ```
# The "weight" function used in prediction have have two possible values:
#
# ‘uniform’ : uniform weights. All points in each neighborhood are weighted equally.
#
# ‘distance’ : weight points by the inverse of their distance. in this case, closer neighbors of a query point will have a greater influence than neighbors which are further away.
# ```

# %%
''' 
Use the K-nearest-neighbor algorithm to classify the iris flowers based on two of their characteristics (sepal length and sepal width.)
'''

# Import needed data science and visualization libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

# Set the value of n_neighbours to 15
n_neighbors = 15

# import  the iris dataset 
iris = datasets.load_iris()

# Only take the first two features. We could avoid this ugly
# slicing by using a two-dim dataset
X = iris.data[:, :2]
y = iris.target

h = .02  # step size in the mesh

# Create color maps
cmap_light = ListedColormap(['orange', 'cyan', 'cornflowerblue'])
cmap_bold = ['darkorange', 'c', 'darkblue']

for weights in ['uniform', 'distance']:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    
    # Make a prediction
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure(figsize=(8, 6))
    plt.contourf(xx, yy, Z, cmap=cmap_light)

    # Plot  the training points 
    sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=iris.target_names[y],
                    palette=cmap_bold, alpha=1.0, edgecolor="black")
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("3-Class classification (k = %i, weights = '%s')"
              % (n_neighbors, weights))
    plt.xlabel(iris.feature_names[0])
    plt.ylabel(iris.feature_names[1])

plt.show()

# %% [markdown]
# ## **References**
# https://colab.research.google.com/
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
#
# https://en.wikipedia.org/wiki/Iris_flower_data_set
#
#
#
# Images Credits:
#
# Inbox classifier: Google
#
# CKD classifier: UC Berkely
#
# KNN: Wikipedia
#
# Iris: Wikipedia
